# %%
class MochilaGenetica:
    # ... (previous code remains unchanged)

    def solve_knapsack(self):
        fitness_evolution = []  # List to store fitness values for each generation
        population_fitness = []  # List to store fitness values for each individual in the population

        # Inicializar população aleatória
        self.populacao = [self.criar_cromossomo() for _ in range(self.tamanho_populacao)]

        for _ in range(self.num_geracoes):
            nova_populacao = []
            generation_fitness = []  # List to store fitness values for individuals in the current generation

            # Elitismo: manter os melhores indivíduos na nova população
            num_elitismo = int(self.taxa_elitismo * self.tamanho_populacao)
            melhores_cromossomos = sorted(self.populacao, key=lambda cromossomo: self.calcular_fitness(cromossomo), reverse=True)[:num_elitismo]
            nova_populacao.extend(melhores_cromossomos)

            # Calcular fitness para indivíduos no elitismo
            for cromossomo in melhores_cromossomos:
                generation_fitness.append(self.calcular_fitness(cromossomo))

            # Completar a nova população com filhos de cruzamento e indivíduos mutados
            while len(nova_populacao) < self.tamanho_populacao:
                pai1 = self.selecao()
                pai2 = self.selecao()

                if random.random() < self.taxa_cruzamento:
                    filho1, filho2 = self.cruzamento(pai1, pai2)
                else:
                    filho1, filho2 = pai1, pai2

                if random.random() < self.taxa_mutacao:
                    filho1 = self.mutacao(filho1)
                if random.random() < self.taxa_mutacao:
                    filho2 = self.mutacao(filho2)

                nova_populacao.extend([filho1, filho2])
                generation_fitness.extend([self.calcular_fitness(filho1), self.calcular_fitness(filho2)])

            # Armazenar fitness values for each individual in the current generation
            population_fitness.append(generation_fitness)

            self.populacao = nova_populacao

        # Construir a lista de itens selecionados com base no melhor cromossomo
        melhor_cromossomo = max(self.populacao, key=lambda cromossomo: self.calcular_fitness(cromossomo))
        melhor_valor = self.calcular_fitness(melhor_cromossomo)
        itens_selecionados = [self.itens[i] for i in range(len(melhor_cromossomo)) if melhor_cromossomo[i] == 1]

        # Retornar uma tupla com a lista de fitness values para cada indivíduo em cada geração, o melhor cromossomo e a lista de itens selecionados
        return population_fitness, (melhor_valor, sum(melhor_cromossomo[i] * self.itens[i].peso for i in range(len(melhor_cromossomo))), melhor_cromossomo), itens_selecionados

# %%
import matplotlib.pyplot as plt
from statistics import median, mean

def plot_lists(max_list, mean_list, min_list, list2, param):
    """
    Plots the values of max_list, mean_list, and min_list against list2.
    
    Args:
    max_list (list): List of maximum fitness values.
    mean_list (list): List of mean fitness values.
    min_list (list): List of minimum fitness values.
    list2 (list): Second list of values.
    """
    # Check if the input lists are of the same length
    if len(max_list) != len(mean_list) or len(mean_list) != len(min_list) or len(min_list) != len(list2):
        print("Error: Input lists must be of the same length.")
        return
    
    # Plotting the graph
    plt.figure(figsize=(8, 6))
    plt.plot(list2, max_list, marker='o', linestyle='-', color='r', label='Max Fitness')
    plt.plot(list2, mean_list, marker='o', linestyle='-', color='g', label='Mean Fitness')
    plt.plot(list2, min_list, marker='o', linestyle='-', color='b', label='Min Fitness')
    plt.xlabel(f'{param}')
    plt.ylabel('Fitness')
    plt.title(f'Plot of Fitness Values against {param}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
from statistics import median, mean
from tqdm import tqdm
import random

def run_experiment(tamanho_mochila, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes_list, itens):
    max_fitness_values = []
    mean_fitness_values = []
    min_fitness_values = []
    
    for num_geracoes in num_geracoes_list:
        fitness_values = []
        for _ in tqdm(range(10)):
            ga = MochilaGenetica(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
            termo1, fitness_evolution, itens_selecionados = ga.solve_knapsack()
            melhor_valor, melhor_peso, melhor_cromossomo = termo1            
            fitness = ga.calcular_fitness(melhor_cromossomo)
            fitness_values.append(fitness)
        
        max_fitness_values.append(max(fitness_values))
        mean_fitness_values.append(mean(fitness_values))
        min_fitness_values.append(min(fitness_values))
    
    return max_fitness_values, mean_fitness_values, min_fitness_values

def variate_param_and_plot():
    # Defina a lista de itens com pesos e valores aleatórios
    numero_de_itens = 10  # Defina o número de itens que você deseja na lista
    itens = [Item(peso=random.randint(1, 20), valor=random.randint(1, 50)) for _ in range(numero_de_itens)]

    # Parâmetros para o experimento
    tamanho_mochila = 15
    tamanho_populacao = 6
    taxa_cruzamento = 0.53
    taxa_mutacao = 0.013
    taxa_elitismo = 0.15
    num_geracoes_list = [50 , 100, 150, 200, 300, 400, 500]

    # Execute the experiment and plot the results
    max_fitness, mean_fitness, min_fitness = run_experiment(tamanho_mochila, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes_list, itens)
    plot_lists(max_fitness, mean_fitness, min_fitness, num_geracoes_list, 'num_geraçoes')
    
    
def run_experiment_10_times(tamanho_mochila, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes_list, itens):
    max_fitness_values = []
    mean_fitness_values = []
    min_fitness_values = []
    
    for num_geracoes in num_geracoes_list:
        fitness_values = []
        for _ in tqdm(range(10)):
            ga = MochilaGenetica(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
            termo1, fitness_evolution, itens_selecionados = ga.solve_knapsack()
            melhor_valor, melhor_peso, melhor_cromossomo = termo1            
            fitness = ga.calcular_fitness(melhor_cromossomo)
            fitness_values.append(fitness)
        
        max_fitness_values.append(max(fitness_values))
        mean_fitness_values.append(mean(fitness_values))
        min_fitness_values.append(min(fitness_values))
    
    return max_fitness_values, mean_fitness_values, min_fitness_values

    

def run_10_times_and_get_metrics():
    # Defina a lista de itens com pesos e valores aleatórios
    numero_de_itens = 10  # Defina o número de itens que você deseja na lista
    itens = [Item(peso=random.randint(1, 20), valor=random.randint(1, 50)) for _ in range(numero_de_itens)]

    # Parâmetros para o experimento
    tamanho_mochila = 15
    tamanho_populacao = 6
    taxa_cruzamento = 0.53
    taxa_mutacao = 0.013
    taxa_elitismo = 0.15
    num_geracoes_list = [50 , 100, 150, 200, 300, 400, 500]

    # Execute the experiment and plot the results
    max_fitness, mean_fitness, min_fitness = run_experiment_10_times(tamanho_mochila, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes_list, itens)
    plot_lists(max_fitness, mean_fitness, min_fitness, num_geracoes_list, 'num_geraçoes')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.93it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

def executar_algoritmo_e_plotar(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes):
    mochila_genetica = MochilaGenetica(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
    
    # Executar o algoritmo e coletar valores de fitness
    melhor_solucao, fitness_evolution, _ = mochila_genetica.solve_knapsack()

    # Calcular fitness médio, do melhor e do pior indivíduo em cada geração
    fitness_evolution = np.array(fitness_evolution)  # Converter para numpy array para facilitar as operações
    fitness_medio = np.mean(fitness_evolution)
    fitness_minimo = np.min(fitness_evolution)
    fitness_maximo = np.max(fitness_evolution)

    # Criar o plot
    geracoes = np.arange(1, num_geracoes + 1)
    plt.figure(figsize=(10, 6))
    plt.plot(geracoes, fitness_medio, label='Fitness Médio', color='blue')
    plt.plot(geracoes, fitness_minimo, label='Fitness do Pior Indivíduo', color='red')
    plt.plot(geracoes, fitness_maximo, label='Fitness do Melhor Indivíduo', color='green')
    plt.xlabel('Número de Gerações')
    plt.ylabel('Fitness')
    plt.legend()
    plt.title('Evolução da Aptidão ao Longo das Gerações')
    plt.grid(True)
    plt.show()

# Parâmetros do problema da mochila
tamanho_mochila = 50
itens = [Item(peso=10, valor=60), Item(peso=20, valor=100), Item(peso=30, valor=120)]
tamanho_populacao = 50
taxa_cruzamento = 0.8
taxa_mutacao = 0.2
taxa_elitismo = 0.1
num_geracoes = 100

# Executar o algoritmo e plotar os gráficos
executar_algoritmo_e_plotar(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2564\1098820926.py in <module>
#      43
#      44 # Executar o algoritmo e plotar os gráficos
# ---> 45 executar_algoritmo_e_plotar(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
#      46
#
# ~\AppData\Local\Temp\ipykernel_2564\1098820926.py in executar_algoritmo_e_plotar(tamanho_mochila, itens, tamanho_populacao, taxa_cruzamento, taxa_mutacao, taxa_elitismo, num_geracoes)
#      23     geracoes = np.arange(1, num_geracoes + 1)
#      24     plt.figure(figsize=(10, 6))
# ---> 25     plt.plot(geracoes, fitness_medio, label='Fitness Médio', color='blue')
#      26     plt.plot(geracoes, fitness_minimo, label='Fitness do Pior Indivíduo', color='red')
# ...
